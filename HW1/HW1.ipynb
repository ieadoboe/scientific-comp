# %% [markdown]
# # CMSC6950 Homework #1
#
# Isaac Adoboe - ieadoboe@mun.ca

# %% [markdown]
# Before I start the assignment, I created this python notebook and a images folder to store the screenshots for the assignments. Below is how the folder looks now.

# %% [markdown]
# ![Screenshot 2025-09-19 at 10.19.59 PM.png](<attachment:Screenshot 2025-09-19 at 10.19.59 PM.png>)

# %% [markdown]
# ![Screenshot 2025-09-19 at 10.18.52 PM.png](<attachment:Screenshot 2025-09-19 at 10.18.52 PM.png>)

# %% [markdown]
# ### Question 1

# %% [markdown]
# Make `isaac_CMSC6950` directory

# %% [markdown]
# ![Screenshot 2025-09-19 at 10.25.52 PM.png](<attachment:Screenshot 2025-09-19 at 10.25.52 PM.png>)

# %% [markdown]
# ![Screenshot 2025-09-19 at 10.26.41 PM.png](<attachment:Screenshot 2025-09-19 at 10.26.41 PM.png>)

# %% [markdown]
# Create `202384695` text file

# %% [markdown]
# ![Screenshot 2025-09-19 at 10.30.48 PM.png](<attachment:Screenshot 2025-09-19 at 10.30.48 PM.png>)

# %% [markdown]
# ![Screenshot 2025-09-19 at 10.35.03 PM.png](<attachment:Screenshot 2025-09-19 at 10.35.03 PM.png>)

# %% [markdown]
# Show contents and change to home directory

# %% [markdown]
# ![Screenshot 2025-09-19 at 10.32.32 PM.png](<attachment:Screenshot 2025-09-19 at 10.32.32 PM.png>)

# %% [markdown]
# ### Question 2

# %% [markdown]
# Create `copmutational_science.txt` and renaming it

# %% [markdown]
# ![Screenshot 2025-09-19 at 10.43.28 PM.png](<attachment:Screenshot 2025-09-19 at 10.43.28 PM.png>)

# %% [markdown]
# ![Screenshot 2025-09-19 at 10.42.47 PM.png](<attachment:Screenshot 2025-09-19 at 10.42.47 PM.png>)

# %% [markdown]
# Remove `computational_science.txt` and create `copmutational_science.txt`

# %% [markdown]
# ![Screenshot 2025-09-19 at 10.49.47 PM.png](<attachment:Screenshot 2025-09-19 at 10.49.47 PM.png>)

# %% [markdown]
# ### Question 3

# %% [markdown]
# Before adding the `alkanes` folder

# %% [markdown]
# ![Screenshot 2025-09-19 at 10.58.10 PM.png](<attachment:Screenshot 2025-09-19 at 10.58.10 PM.png>)

# %% [markdown]
# Copy `alkanes.zip` folder to working directory and unzipping

# %% [markdown]
# ![Screenshot 2025-09-19 at 11.01.01 PM.png](<attachment:Screenshot 2025-09-19 at 11.01.01 PM.png>)

# %% [markdown]
# ![Screenshot 2025-09-19 at 11.01.45 PM.png](<attachment:Screenshot 2025-09-19 at 11.01.45 PM.png>)

# %% [markdown]
# Total number of lines in all files

# %% [markdown]
# ![Screenshot 2025-09-21 at 10.20.43 PM.png](<attachment:Screenshot 2025-09-21 at 10.20.43 PM.png>)

# %% [markdown]
# How many of the compounds have more than 6 atom’s listed in their file?

# %% [markdown]
# ![Screenshot 2025-09-21 at 10.46.10 PM.png](<attachment:Screenshot 2025-09-21 at 10.46.10 PM.png>)

# %% [markdown]
# List the files in order of the decreasing number of lines.

# %% [markdown]
# ![Screenshot 2025-09-21 at 10.49.38 PM.png](<attachment:Screenshot 2025-09-21 at 10.49.38 PM.png>)
